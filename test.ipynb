# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/DD/Desktop/Data Analyst/FoodPrice_in_Turkey.csv')
df
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
df.describe(include='all')
# Out:
#                    Place    ProductId    ProductName         UmId UmName  \
# count               7381  7381.000000           7381  7381.000000   7381
# unique                 4          NaN             52          NaN      9
# top     National Average          NaN  Rice - Retail          NaN     KG
# freq                2633          NaN            174          NaN   5636
# mean                 NaN   254.509687            NaN    15.252811    NaN
# std                  NaN   141.008599            NaN    25.276665    NaN
# min                  NaN    52.000000            NaN     5.000000    NaN
# 25%                  NaN   114.000000            NaN     5.000000    NaN
# 50%                  NaN   239.000000            NaN     5.000000    NaN
# 75%                  NaN   388.000000            NaN     5.000000    NaN
# max                  NaN   502.000000            NaN   102.000000    NaN
#
#               Month         Year        Price
# ...

# %%
df['Place'].count()
# Out:
# 7381

# %%
df.loc[:,'Place':'ProductName'].count()
# Out:
# Place          7381
# ProductId      7381
# ProductName    7381
# dtype: int64

# %%
df['Place'][df['Place']=='National Average'].count()
# Out:
# 2633

# %%
for city in df['Place'].unique():
    print('Số lần xuất hiện của '+city+' là: '+str(df['Place'][df['Place']==city].count()))
# Out:
# Số lần xuất hiện của National Average là: 2633
# Số lần xuất hiện của Ankara là: 1582
# Số lần xuất hiện của Istanbul là: 1583
# Số lần xuất hiện của Izmir là: 1583

# %%
df.loc[:,'Place'].value_counts()
# Out:
# National Average    2633
# Istanbul            1583
# Izmir               1583
# Ankara              1582
# Name: Place, dtype: int64

# %%
df.loc[:,'Place'].value_counts().max()
# Out:
# 2633

# %%
df['Place'][df['Place']==df['Place'].mode().item()].count()
# Out:
# Place          2633
# ProductId      2633
# ProductName    2633
# UmId           2633
# UmName         2633
# Month          2633
# Year           2633
# Price          2633
# dtype: int64

# %%
df[df['Place']==df.loc[:,'Place'].mode().item()]
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 2628  National Average        502  Cocoa (powder) - Retail     5     KG
# 2629  National Average        502  Cocoa (powder) - Retail     5     KG
# 2630  National Average        502  Cocoa (powder) - Retail     5     KG
# 2631  National Average        502  Cocoa (powder) - Retail     5     KG
# 2632  National Average        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
df['Place'].describe()
# Out:
# count                 7381
# unique                   4
# top       National Average
# freq                  2633
# Name: Place, dtype: object

# %%
df.loc[:,'Price'].quantile(0.5)
# Out:
# 5.9096

# %%
df.loc[:,'Price'].quantile(0.25)
# Out:
# 3.2236

# %%
df1 = df.loc[:5,:]
df2 = df.loc[6:,:]
df1
df2
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 6     National Average         52            Rice - Retail     5     KG
# 7     National Average         52            Rice - Retail     5     KG
# 8     National Average         52            Rice - Retail     5     KG
# 9     National Average         52            Rice - Retail     5     KG
# 10    National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 6         3  2014   6.0014
# 7         5  2014   6.3202
# ...
