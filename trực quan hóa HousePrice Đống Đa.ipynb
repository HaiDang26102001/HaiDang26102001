# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/DD/Desktop/Data Analyst/house_price_Dống-Da_Hà-Nội_subdata.csv')
df
# Out:
#       area    price  postDate land_certificate house_direction  \
# 0     50.0  14700.0     44197            So do             NaN
# 1     57.0   4200.0     44265            So do             Nam
# 2     62.0  11000.0     44268            So do             NaN
# 3     26.0   2900.0     44292            So do             NaN
# 4     40.0   3950.0     44292            So do             NaN
# ..     ...      ...       ...              ...             ...
# 666  168.0  23500.0     44325              NaN             NaN
# 667   65.0  17500.0     44325            So do             NaN
# 668   60.0  17500.0     44197              NaN             NaN
# 669   45.0  24800.0     44197              NaN             NaN
# 670  107.0  45000.0     44325            So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0                 NaN     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
c1 = pd.DataFrame(df.groupby('area')['price'].mean())
c1
# Out:
#             price
# area
# 0.0        3398.0
# 14.0       1480.0
# 20.0       2000.0
# 21.0       2450.0
# 22.0        450.0
# ...           ...
# 420.0    215000.0
# 890.0    995000.0
# 1000.0   703750.0
# 4450.0    50000.0
# 11000.0  330000.0
#
# [127 rows x 1 columns]

# %%
c1['price']
# Out:
# area
# 0.0          3398.0
# 14.0         1480.0
# 20.0         2000.0
# 21.0         2450.0
# 22.0          450.0
#              ...
# 420.0      215000.0
# 890.0      995000.0
# 1000.0     703750.0
# 4450.0      50000.0
# 11000.0    330000.0
# Name: price, Length: 127, dtype: float64

# %%
c1.index
# Out:
# Float64Index([    0.0,    14.0,    20.0,    21.0,    22.0,    23.0,    25.0,
#                  26.0,    27.0,    28.0,
#               ...
#                 300.0,   365.0,   368.0,   410.0,   416.0,   420.0,   890.0,
#                1000.0,  4450.0, 11000.0],
#              dtype='float64', name='area', length=127)

# %%
plt.plot(c1.index,c1['price']/1000,marker='o',color='r')
plt.show()

# %%
c2 = pd.DataFrame(df.groupby('bedroom')['price'].mean())
c2
# Out:
#                  price
# bedroom
# 1.0       21137.500000
# 2.0        6310.360870
# 3.0       13910.135135
# 4.0       11464.642857
# 5.0       19144.827586
# 6.0       21034.042553
# 7.0       19315.000000
# 8.0       23314.285714
# 9.0       21333.333333
# 10.0     352320.000000
# 11.0      12750.000000
# 12.0      20550.000000
# 14.0      30250.000000
# 22.0      41000.000000

# %%
plt.plot(c2.index,c2['price'],marker='o',color='r')
plt.show()

# %%
c3 = pd.DataFrame(df.groupby('toilet')['price'].mean())
c3
# Out:
#                price
# toilet
# 1.0      9429.574545
# 2.0      6367.391304
# 3.0     13741.081081
# 4.0      9480.793651
# 5.0     17992.857143
# 6.0     26328.571429
# 7.0     23500.000000
# 8.0     34342.857143
# 10.0    14500.000000
# 11.0    12750.000000
# 12.0    33100.000000
# 16.0    34000.000000

# %%
plt.plot(c3.index,c3['price'],marker='o',color='r')
plt.show()

# %%
df['giá (triệu/m2)'] = df['price']/df['area']
df
# Out:
#       area    price  postDate land_certificate house_direction  \
# 0     50.0  14700.0     44197            So do             NaN
# 1     57.0   4200.0     44265            So do             Nam
# 2     62.0  11000.0     44268            So do             NaN
# 3     26.0   2900.0     44292            So do             NaN
# 4     40.0   3950.0     44292            So do             NaN
# ..     ...      ...       ...              ...             ...
# 666  168.0  23500.0     44325              NaN             NaN
# 667   65.0  17500.0     44325            So do             NaN
# 668   60.0  17500.0     44197              NaN             NaN
# 669   45.0  24800.0     44197              NaN             NaN
# 670  107.0  45000.0     44325            So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0                 NaN     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
df['giá (triệu/m2)'].fillna(value=0,inplace=True)

# %%
L = list(df[df['property_type'] == 'trong ngo']['giá (triệu/m2)'])
for i in L:
    try:
        i = int(i)
    except:
        print(i)
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
df[df['giá (triệu/m2)'] == 'inf'] = 0

# %%
c4 = pd.DataFrame(df.groupby('property_type')['giá (triệu/m2)'].mean())
c4
# Out:
#                giá (triệu/m2)
# property_type
# mat pho            355.373179
# trong ngo                 NaN

# %%
for i in range(len(df['giá (triệu/m2)'])):
    try:
        df.loc[i,'giá (triệu/m2)'] = int(df.loc[i,'giá (triệu/m2)'])
    except:
        df.loc[i,'giá (triệu/m2)'] = 0

# %%
c4 = pd.DataFrame(df.groupby('property_type')['giá (triệu/m2)'].mean())
c4
# Out:
#                giá (triệu/m2)
# property_type
# mat pho            355.009009
# trong ngo          119.975501

# %%
plt.bar(c4.index,c4['giá (triệu/m2)'])
plt.show()

# %%
df
# Out:
#       area    price  postDate land_certificate house_direction  \
# 0     50.0  14700.0     44197            So do             NaN
# 1     57.0   4200.0     44265            So do             Nam
# 2     62.0  11000.0     44268            So do             NaN
# 3     26.0   2900.0     44292            So do             NaN
# 4     40.0   3950.0     44292            So do             NaN
# ..     ...      ...       ...              ...             ...
# 666  168.0  23500.0     44325              NaN             NaN
# 667   65.0  17500.0     44325            So do             NaN
# 668   60.0  17500.0     44197              NaN             NaN
# 669   45.0  24800.0     44197              NaN             NaN
# 670  107.0  45000.0     44325            So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0                 NaN     4.0      6.0    6.0  21.015698  105.824583
# ...
