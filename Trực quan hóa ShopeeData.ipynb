# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/DD/Desktop/Data Analyst/shopeep_koreantop_clothing_shop_data.csv')
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count response_time  \
# ...

# %%
c1 = df.groupby('join_year').count()
c1
# Out:
#            pk_shop  date_collected  shopid  name  join_month  join_day  \
# join_year
# 2015             4               4       4     4           4         4
# 2016            27              27      27    27          27        27
# 2017           156             156     156   156         156       156
# 2018            87              87      87    87          87        87
# 2019           106             106     106   106         106       106
# 2020           247             247     247   247         247       247
# 2021           119             119     119   119         119       119
#
#            item_count  follower_count  response_time  response_rate  \
# join_year
# 2015                4               4              4              4
# 2016               27              27             27             27
# 2017              156             156            156            156
# 2018               87              87             87             87
# ...

# %%
plt.bar(c1.index,c1['shopid'])
plt.show()

# %%
c2 = df.loc[:,['response_rate','rating_good']]
c2
# Out:
#      response_rate  rating_good
# 0               96        17510
# 1               73         2656
# 2               90      1071829
# 3               94        18959
# 4               89        39252
# ..             ...          ...
# 741             86           32
# 742             91            9
# 743             96          463
# 744             73       103289
# 745             36       708666
#
# [746 rows x 2 columns]

# %%
c2.sort_values(by='response_rate',inplace=True)
c2
# Out:
#      response_rate  rating_good
# 145              1         7086
# 224              3       151821
# 254              7        22592
# 319              8         3950
# 57               8        21834
# ..             ...          ...
# 602            100         1798
# 309            100        31403
# 606            100          215
# 693            100            0
# 629            100         2212
#
# [746 rows x 2 columns]

# %%
plt.plot(c2['response_rate'],c2['rating_good'])
plt.show()

# %%
df['response_time'] = pd.to_datetime(df['response_time'],format=' %H:%M:%S')

# %%
df['response_time_second'] = (df['response_time'].dt.hour*60 + df['response_time'].dt.minute)*60 + df['response_time'].dt.second
df
# Out:
#                pk_shop date_collected     shopid                  name  \
# 0    20210613254711738     2021-06-13  254711738          hello.may.ph
# 1    20210613314198143     2021-06-13  314198143       love.women.shop
# 2     2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3     2021061321407329     2021-06-13   21407329           patriciacai
# 4     2021061311187885     2021-06-13   11187885  Little Market Manila
# ..                 ...            ...        ...                   ...
# 741  20210706449182992     2021-07-06  449182992     Yacent_thrift_Clo
# 742  20210706396605392     2021-07-06  396605392           Akistore.ph
# 743  20210706360379308     2021-07-06  360379308          Yzanice Shop
# 744   2021070629392066     2021-07-06   29392066        Clairecvc Shop
# 745   2021070625811092     2021-07-06   25811092           angelcity.💋
#
#     join_month  join_day  join_year  item_count  follower_count  \
# ...

# %%
c3 = df.loc[:,['rating_bad','response_time_second']]
c3.sort_values(by='response_time_second',inplace=True)
c3
# Out:
#      rating_bad  response_time_second
# 203          79                 28801
# 189         276                 28801
# 605          14                 28811
# 692           2                 28812
# 67           37                 28813
# ..          ...                   ...
# 306          79                 49057
# 136           8                 49478
# 636           1                 50499
# 24            0                 53784
# 640           0                 62215
#
# [746 rows x 2 columns]

# %%
plt.plot(c3['response_time_second'],c3['rating_bad'])
plt.show()

# %%
plt.plot(c1.index,c1['shopid'])
plt.show()

# %%
plt.hist(df['rating_normal'])
plt.show()
